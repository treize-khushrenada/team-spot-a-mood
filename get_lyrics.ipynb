# %%
import os
import json
import csv
import time
import spotipy
import lyricsgenius as lg

import numpy as np
import pandas as pd

#import credential
import requests
from spotipy.oauth2 import SpotifyClientCredentials

# %%
CLIENT_ID = "9do6EUQVS8WdNZc4NlRKCdoM-jv6t4r2m_6BQCYUkxTGLMc9JXN_2mBIVbytOIs-"
CLIENT_SECRET = "hbC6CW6oJcIBQjIf7cdEt0p_O8ck2LD8N3f-Kajro5EilE_Q-nuqi-OA7nK8sWGhL4fwK1zhKYEbZ5wMuIUTIQ"
CLIENT_ACCESS_TOKEN = "xXeju4S5sFpDZOv5SAjWMwmOjcjTChruhQj6o3rK6O5ROA5mlA9MLx0Zth4S8ljG"

# %%
lg.auth.OAuth2(client_id=CLIENT_ID, redirect_uri="", client_secret=CLIENT_SECRET)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [53], line 1
# ----> 1 lg.auth.OAuth2(client_id=CLIENT_ID, redirect_uri="", client_secret=CLIENT_SECRET)
#
# File ~/miniforge3/envs/spot-a-mood/lib/python3.11/site-packages/lyricsgenius/auth.py:35, in OAuth2.__init__(self, client_id, redirect_uri, client_secret, scope, state, client_only_app)
#      32 def __init__(self, client_id, redirect_uri,
#      33              client_secret=None, scope=None,
#      34              state=None, client_only_app=False):
# ---> 35     super().__init__()
#      36     msg = ("You must provide a client_secret "
#      37            "if you intend to use the full code exchange."
#      38            "\nIf you meant to use the client-only flow, "
#      39            "set the client_only_app parameter to True.")
#      40     assert any([client_secret, client_only_app]), msg
#
# ...

# %%
genius = lg.Genius(CLIENT_ACCESS_TOKEN)

# %%
df = pd.read_csv('charts.csv')

# %%
df.head()
# Out:
#          date  rank           song                         artist  last-week  \
# 0  2021-11-06     1     Easy On Me                          Adele        1.0
# 1  2021-11-06     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2  2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
# 3  2021-11-06     4     Fancy Like                   Walker Hayes        4.0
# 4  2021-11-06     5     Bad Habits                     Ed Sheeran        5.0
#
#    peak-rank  weeks-on-board
# 0          1               3
# 1          1              16
# 2          1              14
# 3          3              19
# 4          2              18

# %%
song = genius.search_song("Fancy Like", "Walker Hayes")
# Out:
# Searching for "Fancy Like" by Walker Hayes...
# Done.

# %%
song.lyrics
# Out:
# "INDUSTRY BABY Lyrics[Intro: Lil Nas X]\n(D-D-Daytrip took it to ten, hey)\nBaby back, ayy, couple racks, ayy\nCouple Grammys on him, couple plaques, ayy\nThat's a fact, ayy, throw it back, ayy\nThrow it back, ayy\n[Pre-Chorus: Lil Nas X]\nAnd this one is for the champions\nI ain't lost since I began, yeah\nFunny how you said it was the end, yeah\nThen I went did it again, yeah\n[Chorus: Lil Nas X]\nI told you long ago on the road\nI got what they waiting for\nI don't run from nothing, dog\nGet your soldiers, tell 'em I ain't layin' low\nYou was never really rooting for me anyway\nWhen I'm back up at the top, I wanna hear you say\nHe don't run from nothin', dog\nGet your soldiers, tell 'em that the break is over\n\n[Verse 1: Lil Nas X]\nUh, need to, uh\nNeed to get this album done\nNeed a couple number onеs\nNeed a plaque on every song\nNeed mе like one with Nicki now\nTell a rap nigga I don't see ya, hah\nI'm a pop nigga like Bieber, hah\nI don't fuck bitches, I'm queer, hah\nBut th
# ...

# %%
song = genius.search_song("Aural Apocalypse", "A Different Breed Of Killer")
song.lyrics
# Out:
# Searching for "Aural Apocalypse" by A Different Breed Of Killer...
# Done.
# ...

# %%
song.id
# Out:
# 7260084

# %%
song = genius.song(7260084)

# %%
song
# Out:
# {'song': {'annotation_count': 7,
#   'api_path': '/songs/7260084',
#   'apple_music_id': '1590036021',
#   'apple_music_player_url': 'https://genius.com/songs/7260084/apple_music_player',
#   'artist_names': 'Adele',
# ...

# %%
genius.song_annotations(7260084)
# Out:
# [('[Chorus]',
#   [['Adele explained this chorus on an interview with ELLE for their “Life in Lyrics,” saying:\n\nThat makes me think about how lost I was when I was in my marriage. I wrote the verse to “Easy On Me” in the shower, then I wrote the chorus later that day. A lot of my friends throughout that rainy period of my life kept saying to me, “You have to go easy on yourself, don’t beat yourself up too much about your decisions, you just gotta give it time” and stuff like that, and it just really, really stuck with me, that I have to be kind to myself, and that it’s incredibly layered what I was going through. So, that’s where “Easy On Me” comes from, and I love that lyric: “I had no time to choose what I chose to do.”']]),
#  ('There ain’t no gold in this river\n That I’ve been washin’ my hands in forever\n I know there is hope in these waters\n But I can’t bring myself to swim\n When I am drowning in this silence\n Baby, let me in',
# ...

# %%
type(song)
# Out:
# lyricsgenius.types.song.Song

# %%
mmkey = "15baf4baed0a0939dc72a7c6fea1ea29"

# %%
import json
#from os.path import json, dirname
from musixmatch import Musixmatch

mm = Musixmatch("15baf4baed0a0939dc72a7c6fea1ea29")

match = mm.matcher_lyrics_get('Grenade', 'Bruno Mars')

# %%
mm.matcher_lyrics_get(track_isrc = 'GBBKS1500243')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [123], line 1
# ----> 1 mm.matcher_lyrics_get(track_isrc = 'GBBKS1500243')
#
# TypeError: Musixmatch.matcher_lyrics_get() got an unexpected keyword argument 'track_isrc'

# %%
mm.track_lyrics_get(15953433)
# Out:
# {'message': {'header': {'status_code': 404, 'execute_time': 0.006026029586792},
#   'body': []}}
