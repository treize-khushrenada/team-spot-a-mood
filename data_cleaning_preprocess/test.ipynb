# %%
import numpy as np
import pandas as pd
import os
import nltk
import pickle
import re

from nltk.tokenize import word_tokenize
from sentence_transformers import SentenceTransformer, util
# Out:
# c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\huggingface_hub\snapshot_download.py:6: FutureWarning: snapshot_download.py has been made private and will no longer be available from version 0.11. Please use `from huggingface_hub import snapshot_download` to import the only public function in this module. Other members of the file may be changed without a deprecation notice.
#   warnings.warn(

# %%
songs_set = pd.read_csv('../songsdata/cleaned_data/cleaned_songs.csv')

# %%
songs_set.head()
# Out:
#                 artist                       title  danceability  energy  \
# 0       A Few Good Men                      Tonite         0.615   0.673
# 1       A Few Good Men                Have I Never         0.717   0.377
# 2       A Few Good Men  Don't Cry (Behind My Back)         0.774   0.691
# 3  A Flock Of Seagulls    Modern Love Is Automatic         0.323   0.821
# 4  A Flock Of Seagulls                     Windows         0.629   0.683
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  ...  \
# 0   5.0    -8.501   0.0       0.1150        0.0429             0.000  ...
# 1   4.0    -8.680   1.0       0.0288        0.2820             0.000  ...
# 2  10.0    -6.815   1.0       0.0403        0.0827             0.000  ...
# 3   7.0    -6.245   1.0       0.1090        0.0444             0.979  ...
# 4   0.0   -12.306   1.0       0.0324        0.1200             0.480  ...
#
#    valence    tempo  duration  time_signature  \
# 0    0.831  178.124  254360.0             4.0
# 1    0.161  120.036  336533.0             4.0
# 2    0.850  134.050  308267.0             4.0
# 3    0.192  162.700  230200.0             4.0
# 4    0.708  150.083  210827.0             4.0
#
#                                               lyrics  genius_id  annotation  \
# 0  Tonite LyricsYou know I really want to love yo...  1382268.0          []
# 1  Have I Never LyricsHave I never told you I lov...  1187594.0          []
# 2  Don’t Cry (Behind My Back) LyricsDon't cry, do...   897142.0          []
# 3  Modern Love Is Automatic LyricsShe's an automa...   969269.0          []
# 4  Windows LyricsMy phobia has got me and I dare ...  1510901.0          []
#
#                                          lyrics_list  line_len  song_len
# 0  ['Tonite LyricsYou know I really want to love ...  6.666667        66
# 1  ['Have I Never LyricsHave I never told you I l...  8.196078        51
# 2  ["Don’t Cry (Behind My Back) LyricsDon't cry, ...  5.371429        70
# 3  ["Modern Love Is Automatic LyricsShe's an auto...  3.147059        34
# 4  ['Windows LyricsMy phobia has got me and I dar...  8.758621        29
#
# [5 rows x 21 columns]

# %%
model = SentenceTransformer("all-distilroberta-v1")
embeddings = model.encode(songs_set['lyrics'], convert_to_tensor=True)
embeddings
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\poomk\OneDrive\Desktop\songsdata\data_cleaning_preprocess\test.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/poomk/OneDrive/Desktop/songsdata/data_cleaning_preprocess/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> model = SentenceTransformer("all-distilroberta-v1")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/poomk/OneDrive/Desktop/songsdata/data_cleaning_preprocess/test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> embeddings = model.encode(songs_set['lyrics'], convert_to_tensor=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/poomk/OneDrive/Desktop/songsdata/data_cleaning_preprocess/test.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> embeddings
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\sentence_transformers\SentenceTransformer.py:160, in SentenceTransformer.encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     157 features = batch_to_device(features, device)
#     159 with torch.no_grad():
# --> 160     out_features = self.forward(features)
#     162     if output_value == 'token_embeddings':
#     163         embeddings = []
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\torch\nn\modules\container.py:141, in Sequential.forward(self, input)
#     139 def forward(self, input):
#     140     for module in self:
# --> 141         input = module(input)
#     142     return input
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\sentence_transformers\models\Transformer.py:51, in Transformer.forward(self, features)
#      48 if 'token_type_ids' in features:
#      49     trans_features['token_type_ids'] = features['token_type_ids']
# ---> 51 output_states = self.auto_model(**trans_features, return_dict=False)
#      52 output_tokens = output_states[0]
#      54 cls_tokens = output_tokens[:, 0, :]  # CLS token is first token
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\transformers\models\roberta\modeling_roberta.py:851, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     842 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     844 embedding_output = self.embeddings(
#     845     input_ids=input_ids,
#     846     position_ids=position_ids,
#    (...)
#     849     past_key_values_length=past_key_values_length,
#     850 )
# --> 851 encoder_outputs = self.encoder(
#     852     embedding_output,
#     853     attention_mask=extended_attention_mask,
#     854     head_mask=head_mask,
#     855     encoder_hidden_states=encoder_hidden_states,
#     856     encoder_attention_mask=encoder_extended_attention_mask,
#     857     past_key_values=past_key_values,
#     858     use_cache=use_cache,
#     859     output_attentions=output_attentions,
#     860     output_hidden_states=output_hidden_states,
#     861     return_dict=return_dict,
#     862 )
#     863 sequence_output = encoder_outputs[0]
#     864 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\transformers\models\roberta\modeling_roberta.py:527, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     518     layer_outputs = torch.utils.checkpoint.checkpoint(
#     519         create_custom_forward(layer_module),
#     520         hidden_states,
#    (...)
#     524         encoder_attention_mask,
#     525     )
#     526 else:
# --> 527     layer_outputs = layer_module(
#     528         hidden_states,
#     529         attention_mask,
#     530         layer_head_mask,
#     531         encoder_hidden_states,
#     532         encoder_attention_mask,
#     533         past_key_value,
#     534         output_attentions,
#     535     )
#     537 hidden_states = layer_outputs[0]
#     538 if use_cache:
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\transformers\models\roberta\modeling_roberta.py:413, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     401 def forward(
#     402     self,
#     403     hidden_states: torch.Tensor,
#    (...)
#     410 ) -> Tuple[torch.Tensor]:
#     411     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     412     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 413     self_attention_outputs = self.attention(
#     414         hidden_states,
#     415         attention_mask,
#     416         head_mask,
#     417         output_attentions=output_attentions,
#     418         past_key_value=self_attn_past_key_value,
#     419     )
#     420     attention_output = self_attention_outputs[0]
#     422     # if decoder, the last output is tuple of self-attn cache
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\transformers\models\roberta\modeling_roberta.py:340, in RobertaAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     330 def forward(
#     331     self,
#     332     hidden_states: torch.Tensor,
#    (...)
#     338     output_attentions: Optional[bool] = False,
#     339 ) -> Tuple[torch.Tensor]:
# --> 340     self_outputs = self.self(
#     341         hidden_states,
#     342         attention_mask,
#     343         head_mask,
#     344         encoder_hidden_states,
#     345         encoder_attention_mask,
#     346         past_key_value,
#     347         output_attentions,
#     348     )
#     349     attention_output = self.output(self_outputs[0], hidden_states)
#     350     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\transformers\models\roberta\modeling_roberta.py:266, in RobertaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     263     attention_scores = attention_scores + attention_mask
#     265 # Normalize the attention scores to probabilities.
# --> 266 attention_probs = nn.functional.softmax(attention_scores, dim=-1)
#     268 # This is actually dropping out entire tokens to attend to, which might
#     269 # seem a bit unusual, but is taken from the original Transformer paper.
#     270 attention_probs = self.dropout(attention_probs)
#
# File c:\Users\poomk\miniconda3\envs\dataenv\lib\site-packages\torch\nn\functional.py:1680, in softmax(input, dim, _stacklevel, dtype)
#    1678     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1679 if dtype is None:
# -> 1680     ret = input.softmax(dim)
#    1681 else:
#    1682     ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:
